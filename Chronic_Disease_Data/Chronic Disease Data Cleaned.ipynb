# %%
import pandas as pd

# %%
csv_path = ("Chronic_Disease_Data/U.S._Chronic_Disease_Indicators__CDI_.csv")

csv_df = pd.read_csv(csv_path)
low_memory=False
csv_df.head()
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType  ... LocationID  TopicID QuestionID DataValueTypeID  \
# 0  Crude Prevalence  ...         59      ALC     ALC2_2         CRDPREV
# 1  Crude Prevalence  ...          1      ALC     ALC2_2         CRDPREV
# 2  Crude Prevalence  ...          2      ALC     ALC2_2         CRDPREV
# 3  Crude Prevalence  ...          4      ALC     ALC2_2         CRDPREV
# 4  Crude Prevalence  ...          5      ALC     ALC2_2         CRDPREV
#
#    StratificationCategoryID1  StratificationID1 StratificationCategoryID2  \
# 0                    OVERALL                OVR                       NaN
# 1                    OVERALL                OVR                       NaN
# 2                    OVERALL                OVR                       NaN
# 3                    OVERALL                OVR                       NaN
# 4                    OVERALL                OVR                       NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN
#
# [5 rows x 34 columns]

# %%
del csv_df["DataSource"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType DataValue  ...  LocationID TopicID QuestionID  \
# 0  Crude Prevalence      16.9  ...          59     ALC     ALC2_2
# 1  Crude Prevalence        13  ...           1     ALC     ALC2_2
# 2  Crude Prevalence      18.2  ...           2     ALC     ALC2_2
# 3  Crude Prevalence      15.6  ...           4     ALC     ALC2_2
# 4  Crude Prevalence        15  ...           5     ALC     ALC2_2
#
#    DataValueTypeID  StratificationCategoryID1 StratificationID1  \
# 0          CRDPREV                    OVERALL               OVR
# 1          CRDPREV                    OVERALL               OVR
# 2          CRDPREV                    OVERALL               OVR
# 3          CRDPREV                    OVERALL               OVR
# 4          CRDPREV                    OVERALL               OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 33 columns]

# %%
del csv_df["Response"]


csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...             %
# 1  Binge drinking prevalence among adults aged >=...             %
# 2  Binge drinking prevalence among adults aged >=...             %
# 3  Binge drinking prevalence among adults aged >=...             %
# 4  Binge drinking prevalence among adults aged >=...             %
#
#       DataValueType DataValue  DataValueAlt  ... LocationID TopicID  \
# 0  Crude Prevalence      16.9          16.9  ...         59     ALC
# 1  Crude Prevalence        13          13.0  ...          1     ALC
# 2  Crude Prevalence      18.2          18.2  ...          2     ALC
# 3  Crude Prevalence      15.6          15.6  ...          4     ALC
# 4  Crude Prevalence        15          15.0  ...          5     ALC
#
#    QuestionID  DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0      ALC2_2          CRDPREV                   OVERALL               OVR
# 1      ALC2_2          CRDPREV                   OVERALL               OVR
# 2      ALC2_2          CRDPREV                   OVERALL               OVR
# 3      ALC2_2          CRDPREV                   OVERALL               OVR
# 4      ALC2_2          CRDPREV                   OVERALL               OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 32 columns]

# %%
del csv_df["DataValueType"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... LocationID  TopicID  QuestionID  \
# 0          16.9                       *  ...         59      ALC      ALC2_2
# 1          13.0                     NaN  ...          1      ALC      ALC2_2
# 2          18.2                     NaN  ...          2      ALC      ALC2_2
# 3          15.6                     NaN  ...          4      ALC      ALC2_2
# 4          15.0                     NaN  ...          5      ALC      ALC2_2
#
#   DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0         CRDPREV                   OVERALL               OVR
# 1         CRDPREV                   OVERALL               OVR
# 2         CRDPREV                   OVERALL               OVR
# 3         CRDPREV                   OVERALL               OVR
# 4         CRDPREV                   OVERALL               OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 31 columns]

# %%
del csv_df["TopicID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... ResponseID  LocationID  \
# 0          16.9                       *  ...        NaN          59
# 1          13.0                     NaN  ...        NaN           1
# 2          18.2                     NaN  ...        NaN           2
# 3          15.6                     NaN  ...        NaN           4
# 4          15.0                     NaN  ...        NaN           5
#
#    QuestionID DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0      ALC2_2         CRDPREV                   OVERALL               OVR
# 1      ALC2_2         CRDPREV                   OVERALL               OVR
# 2      ALC2_2         CRDPREV                   OVERALL               OVR
# 3      ALC2_2         CRDPREV                   OVERALL               OVR
# 4      ALC2_2         CRDPREV                   OVERALL               OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 30 columns]

# %%
del csv_df["QuestionID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ...  \
# 0          16.9                       *  ...
# 1          13.0                     NaN  ...
# 2          18.2                     NaN  ...
# 3          15.6                     NaN  ...
# 4          15.0                     NaN  ...
#
#                                  GeoLocation  ResponseID  LocationID  \
# 0                                        NaN         NaN          59
# 1    (32.84057112200048, -86.63186076199969)         NaN           1
# 2   (64.84507995700051, -147.72205903599973)         NaN           2
# 3  (34.865970280000454, -111.76381127699972)         NaN           4
# 4    (34.74865012400045, -92.27449074299966)         NaN           5
#
#   DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0         CRDPREV                   OVERALL               OVR
# 1         CRDPREV                   OVERALL               OVR
# 2         CRDPREV                   OVERALL               OVR
# 3         CRDPREV                   OVERALL               OVR
# 4         CRDPREV                   OVERALL               OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 29 columns]

# %%
del csv_df["DataValueTypeID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... Stratification3  \
# 0          16.9                       *  ...             NaN
# 1          13.0                     NaN  ...             NaN
# 2          18.2                     NaN  ...             NaN
# 3          15.6                     NaN  ...             NaN
# 4          15.0                     NaN  ...             NaN
#
#                                  GeoLocation  ResponseID LocationID  \
# 0                                        NaN         NaN         59
# 1    (32.84057112200048, -86.63186076199969)         NaN          1
# 2   (64.84507995700051, -147.72205903599973)         NaN          2
# 3  (34.865970280000454, -111.76381127699972)         NaN          4
# 4    (34.74865012400045, -92.27449074299966)         NaN          5
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                       NaN
# 1                   OVERALL               OVR                       NaN
# 2                   OVERALL               OVR                       NaN
# 3                   OVERALL               OVR                       NaN
# 4                   OVERALL               OVR                       NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN
#
# [5 rows x 28 columns]

# %%
del csv_df["StratificationCategoryID1"]

# %%
del csv_df["DataValueFootnoteSymbol"]

# %%
del csv_df["StratificationCategory3"]

# %%
del csv_df["Stratification3"]

# %%
del csv_df["DatavalueFootnote"]

# %%
del csv_df["LowConfidenceLimit"]

# %%
del csv_df["HighConfidenceLimit"]

# %%
del csv_df["StratificationCategory1"]

# %%
del csv_df["StratificationCategory2"]

# %%
del csv_df["Stratification2"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt Stratification1                                GeoLocation  \
# 0          16.9         Overall                                        NaN
# 1          13.0         Overall    (32.84057112200048, -86.63186076199969)
# 2          18.2         Overall   (64.84507995700051, -147.72205903599973)
# 3          15.6         Overall  (34.865970280000454, -111.76381127699972)
# 4          15.0         Overall    (34.74865012400045, -92.27449074299966)
#
#   ResponseID  LocationID StratificationID1 StratificationCategoryID2  \
# 0        NaN          59               OVR                       NaN
# 1        NaN           1               OVR                       NaN
# 2        NaN           2               OVR                       NaN
# 3        NaN           4               OVR                       NaN
# 4        NaN           5               OVR                       NaN
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0               NaN                       NaN               NaN
# 1               NaN                       NaN               NaN
# 2               NaN                       NaN               NaN
# 3               NaN                       NaN               NaN
# 4               NaN                       NaN               NaN

# %%
del csv_df["Stratification1"]

# %%
del csv_df["ResponseID"]

# %%
del csv_df["LocationID"]

# %%
del csv_df["StratificationID1"]

# %%
del csv_df["StratificationCategoryID2"]

# %%
del csv_df["StratificationID2"]

# %%
del csv_df["StratificationCategoryID3"]

# %%
del csv_df["StratificationID3"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt                                GeoLocation
# 0          16.9                                        NaN
# 1          13.0    (32.84057112200048, -86.63186076199969)
# 2          18.2   (64.84507995700051, -147.72205903599973)
# 3          15.6  (34.865970280000454, -111.76381127699972)
# 4          15.0    (34.74865012400045, -92.27449074299966)

# %%
csv_df = csv_df.dropna(how="any")

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#    DataValueAlt                                GeoLocation
# 1          13.0    (32.84057112200048, -86.63186076199969)
# 2          18.2   (64.84507995700051, -147.72205903599973)
# 3          15.6  (34.865970280000454, -111.76381127699972)
# 4          15.0    (34.74865012400045, -92.27449074299966)
# 5          16.3   (37.63864012300047, -120.99999953799971)

# %%
del csv_df["DataValueAlt"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#                                  GeoLocation
# 1    (32.84057112200048, -86.63186076199969)
# 2   (64.84507995700051, -147.72205903599973)
# 3  (34.865970280000454, -111.76381127699972)
# 4    (34.74865012400045, -92.27449074299966)
# 5   (37.63864012300047, -120.99999953799971)

# %%
csv_df_2 = csv_df["GeoLocation"].str.split(",", n = 1, expand = True) 

csv_df_2.head()
# Out:
#                      0                      1
# 1   (32.84057112200048    -86.63186076199969)
# 2   (64.84507995700051   -147.72205903599973)
# 3  (34.865970280000454   -111.76381127699972)
# 4   (34.74865012400045    -92.27449074299966)
# 5   (37.63864012300047   -120.99999953799971)

# %%
# csv_df['tmp'] = 9
# csv_df_2['tmp'] = 2

## csv_df_3 = pd.merge(csv_df, csv_df_2, on=['tmp'])
# csv_df_3.head()
# Out:
# Empty DataFrame
# Columns: [YearStart, YearEnd, LocationAbbr, LocationDesc, Topic, Question, DataValueUnit, DataValue, GeoLocation, tmp, 0, 1]
# Index: []

# %%
csv_df["Latitude"] = csv_df_2[0]
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#                                  GeoLocation  tmp             Latitude
# 1    (32.84057112200048, -86.63186076199969)    9   (32.84057112200048
# 2   (64.84507995700051, -147.72205903599973)    9   (64.84507995700051
# 3  (34.865970280000454, -111.76381127699972)    9  (34.865970280000454
# 4    (34.74865012400045, -92.27449074299966)    9   (34.74865012400045
# 5   (37.63864012300047, -120.99999953799971)    9   (37.63864012300047

# %%
csv_df["Longitude"] = csv_df_2[1]
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#                                  GeoLocation  tmp             Latitude  \
# 1    (32.84057112200048, -86.63186076199969)    9   (32.84057112200048
# 2   (64.84507995700051, -147.72205903599973)    9   (64.84507995700051
# 3  (34.865970280000454, -111.76381127699972)    9  (34.865970280000454
# 4    (34.74865012400045, -92.27449074299966)    9   (34.74865012400045
# 5   (37.63864012300047, -120.99999953799971)    9   (37.63864012300047
#
#                Longitude
# 1    -86.63186076199969)
# 2   -147.72205903599973)
# 3   -111.76381127699972)
# 4    -92.27449074299966)
# 5   -120.99999953799971)

# %%
del csv_df["GeoLocation"]

# %%
del csv_df["tmp"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#               Latitude              Longitude
# 1   (32.84057112200048    -86.63186076199969)
# 2   (64.84507995700051   -147.72205903599973)
# 3  (34.865970280000454   -111.76381127699972)
# 4   (34.74865012400045    -92.27449074299966)
# 5   (37.63864012300047   -120.99999953799971)

# %%
replace_lat = csv_df["Latitude"].str.replace("\(","")
csv_df_4 = pd.DataFrame(replace_lat)
csv_df_4.head()
# Out:
#              Latitude
# 1   32.84057112200048
# 2   64.84507995700051
# 3  34.865970280000454
# 4   34.74865012400045
# 5   37.63864012300047

# %%
csv_df["Latitude2"] = csv_df_4["Latitude"]
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#               Latitude              Longitude           Latitude2
# 1   (32.84057112200048    -86.63186076199969)   32.84057112200048
# 2   (64.84507995700051   -147.72205903599973)   64.84507995700051
# 3  (34.865970280000454   -111.76381127699972)  34.865970280000454
# 4   (34.74865012400045    -92.27449074299966)   34.74865012400045
# 5   (37.63864012300047   -120.99999953799971)   37.63864012300047

# %%
replace_lng = csv_df["Longitude"].str.replace("\)","")
csv_df_5 = pd.DataFrame(replace_lng)
csv_df_5.head()
# Out:
#               Longitude
# 1    -86.63186076199969
# 2   -147.72205903599973
# 3   -111.76381127699972
# 4    -92.27449074299966
# 5   -120.99999953799971

# %%
csv_df["Longitude2"] = csv_df_5["Longitude"]
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#               Latitude              Longitude           Latitude2  \
# 1   (32.84057112200048    -86.63186076199969)   32.84057112200048
# 2   (64.84507995700051   -147.72205903599973)   64.84507995700051
# 3  (34.865970280000454   -111.76381127699972)  34.865970280000454
# 4   (34.74865012400045    -92.27449074299966)   34.74865012400045
# 5   (37.63864012300047   -120.99999953799971)   37.63864012300047
#
#              Longitude2
# 1    -86.63186076199969
# 2   -147.72205903599973
# 3   -111.76381127699972
# 4    -92.27449074299966
# 5   -120.99999953799971

# %%
del csv_df["Latitude"]

# %%
del csv_df["Longitude"]

# %%
csv_df = csv_df.rename(columns={
    "Longitude2": "Longitude",
    "Latitude2": "Latitude"
})

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#              Latitude             Longitude
# 1   32.84057112200048    -86.63186076199969
# 2   64.84507995700051   -147.72205903599973
# 3  34.865970280000454   -111.76381127699972
# 4   34.74865012400045    -92.27449074299966
# 5   37.63864012300047   -120.99999953799971

# %%
csv_df.dtypes
# Out:
# YearStart         int64
# YearEnd           int64
# LocationAbbr     object
# LocationDesc     object
# Topic            object
# Question         object
# DataValueUnit    object
# DataValue        object
# Latitude         object
# Longitude        object
# dtype: object

# %%
csv_df["DataValue"] = csv_df["DataValue"].astype(float)

# %%
csv_df.dtypes
# Out:
# YearStart          int64
# YearEnd            int64
# LocationAbbr      object
# LocationDesc      object
# Topic             object
# Question          object
# DataValueUnit     object
# DataValue        float64
# Latitude          object
# Longitude         object
# dtype: object

# %%
csv_df["Longitude"] = csv_df["Longitude"].astype(float)
csv_df["Latitude"] = csv_df["Latitude"].astype(float)

# %%
csv_df.dtypes
# Out:
# YearStart          int64
# YearEnd            int64
# LocationAbbr      object
# LocationDesc      object
# Topic             object
# Question          object
# DataValueUnit     object
# DataValue        float64
# Latitude         float64
# Longitude        float64
# dtype: object

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit  DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %       13.0
# 2  Binge drinking prevalence among adults aged >=...             %       18.2
# 3  Binge drinking prevalence among adults aged >=...             %       15.6
# 4  Binge drinking prevalence among adults aged >=...             %       15.0
# 5  Binge drinking prevalence among adults aged >=...             %       16.3
#
#     Latitude   Longitude
# 1  32.840571  -86.631861
# 2  64.845080 -147.722059
# 3  34.865970 -111.763811
# 4  34.748650  -92.274491
# 5  37.638640 -121.000000

# %%
output_csv = csv_df.to_csv("Cleaned_Chronic_Disease_Data.csv", index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-184-d528fe792a9f> in <module>
# ----> 1 output_csv = csv_df.to_csv("/Cleaned_Chronic_Disease_Data.csv", index=False, header=True)
#
# ~/anaconda3/envs/PythonData3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/envs/PythonData3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~/anaconda3/envs/PythonData3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '/Cleaned_Chronic_Disease_Data.csv'
