# %%
import pandas as pd

# %%
csv_path = ("GDP_Data/bea-gdp-by-state.csv")

csv_df = pd.read_csv(csv_path)
csv_df.head()
# Out:
#    Fips           Area   2013   2014   2015   2016   2017
# 0     0  United States  48534  49329  50301  50660  51337
# 1  1000        Alabama  36674  36473  36818  37158  37508
# 2  2000         Alaska  69711  67179  65971  63304  63610
# 3  4000        Arizona  38352  38534  38787  38940  39583
# 4  5000       Arkansas  35888  36265  36295  36502  36714

# %%
del csv_df["Fips"]
csv_df.head()
# Out:
#             Area   2013   2014   2015   2016   2017
# 0  United States  48534  49329  50301  50660  51337
# 1        Alabama  36674  36473  36818  37158  37508
# 2         Alaska  69711  67179  65971  63304  63610
# 3        Arizona  38352  38534  38787  38940  39583
# 4       Arkansas  35888  36265  36295  36502  36714

# %%
csv_df = csv_df.dropna(how="any")

# %%
renamed_df = csv_df.rename(columns={
    "Area": "State"
})

# %%
renamed_df.head()
# Out:
#            State   2013   2014   2015   2016   2017
# 0  United States  48534  49329  50301  50660  51337
# 1        Alabama  36674  36473  36818  37158  37508
# 2         Alaska  69711  67179  65971  63304  63610
# 3        Arizona  38352  38534  38787  38940  39583
# 4       Arkansas  35888  36265  36295  36502  36714

# %%
renamed_df.dtypes
# Out:
# State    object
# 2013      int64
# 2014      int64
# 2015      int64
# 2016      int64
# 2017      int64
# dtype: object

# %%
new_df = renamed_df.drop([0], axis = 0)
new_df.head()
# Out:
#         State   2013   2014   2015   2016   2017
# 1     Alabama  36674  36473  36818  37158  37508
# 2      Alaska  69711  67179  65971  63304  63610
# 3     Arizona  38352  38534  38787  38940  39583
# 4    Arkansas  35888  36265  36295  36502  36714
# 5  California  53838  55571  57637  58974  60359

# %%
new_df
# Out:
#                    State    2013    2014    2015    2016    2017
# 1                Alabama   36674   36473   36818   37158   37508
# 2                 Alaska   69711   67179   65971   63304   63610
# 3                Arizona   38352   38534   38787   38940   39583
# 4               Arkansas   35888   36265   36295   36502   36714
# 5             California   53838   55571   57637   58974   60359
# 6               Colorado   50523   52105   53007   52863   54026
# 7            Connecticut   62438   62023   62796   62745   62633
# 8               Delaware   60738   63555   64809   63578   63955
# 9   District of Columbia  159264  159369  159530  159141  159607
# 10               Florida   38018   38466   39334   39608   39842
# 11               Georgia   42513   43467   44246   45238   45925
# 12                Hawaii   49484   49591   51052   51964   52869
# 13                 Idaho   34787   35173   35679   36256   36441
# ...

# %%
second_new_df = pd.DataFrame()
second_new_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
second_new_df = new_df.iloc[51:59, :]
second_new_df.head()
# Out:
#           State   2013   2014   2015   2016   2017
# 52  New England  56689  57068  58477  58882  59637
# 53      Mideast  57659  58353  59364  59756  60421
# 54  Great Lakes  46076  47035  47644  48276  49034
# 55       Plains  48092  49005  49473  49919  50145
# 56    Southeast  40543  40910  41547  41867  42300

# %%
second_new_df.to_csv("Cleaned_GDP_Data_Regions.csv", index=False, header=True)

# %%
new_df
# Out:
#                    State    2013    2014    2015    2016    2017
# 1                Alabama   36674   36473   36818   37158   37508
# 2                 Alaska   69711   67179   65971   63304   63610
# 3                Arizona   38352   38534   38787   38940   39583
# 4               Arkansas   35888   36265   36295   36502   36714
# 5             California   53838   55571   57637   58974   60359
# 6               Colorado   50523   52105   53007   52863   54026
# 7            Connecticut   62438   62023   62796   62745   62633
# 8               Delaware   60738   63555   64809   63578   63955
# 9   District of Columbia  159264  159369  159530  159141  159607
# 10               Florida   38018   38466   39334   39608   39842
# 11               Georgia   42513   43467   44246   45238   45925
# 12                Hawaii   49484   49591   51052   51964   52869
# 13                 Idaho   34787   35173   35679   36256   36441
# ...

# %%
cleaned_df = new_df.drop([52, 53, 54, 55, 56, 57, 58, 59], axis = 0)
cleaned_df
# Out:
#                    State    2013    2014    2015    2016    2017
# 1                Alabama   36674   36473   36818   37158   37508
# 2                 Alaska   69711   67179   65971   63304   63610
# 3                Arizona   38352   38534   38787   38940   39583
# 4               Arkansas   35888   36265   36295   36502   36714
# 5             California   53838   55571   57637   58974   60359
# 6               Colorado   50523   52105   53007   52863   54026
# 7            Connecticut   62438   62023   62796   62745   62633
# 8               Delaware   60738   63555   64809   63578   63955
# 9   District of Columbia  159264  159369  159530  159141  159607
# 10               Florida   38018   38466   39334   39608   39842
# 11               Georgia   42513   43467   44246   45238   45925
# 12                Hawaii   49484   49591   51052   51964   52869
# 13                 Idaho   34787   35173   35679   36256   36441
# ...

# %%
cleaned_df.to_csv("Cleaned_GDP_Data.csv", index=False, header=True)
