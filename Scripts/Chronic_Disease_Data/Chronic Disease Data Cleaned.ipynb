# %%
import pandas as pd

# %%
csv_path = ("../U.S._Chronic_Disease_Indicators__CDI_.csv")

csv_df = pd.read_csv(csv_path)
low_memory=False
csv_df
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2016     2016           US         United States
# 1            2016     2016           AL               Alabama
# 2            2016     2016           AK                Alaska
# 3            2016     2016           AZ               Arizona
# 4            2016     2016           AR              Arkansas
# 5            2016     2016           CA            California
# 6            2016     2016           CO              Colorado
# 7            2016     2016           CT           Connecticut
# 8            2016     2016           DE              Delaware
# ...

# %%
csv_df = csv_df[[(x == 'Crude Prevalence') for x in csv_df["DataValueType"]]]
csv_df["DataValueType"].unique()
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType  ... LocationID  TopicID QuestionID DataValueTypeID  \
# ...

# %%
csv_df["Topic"].unique()
# Out:
# array(['Alcohol', 'Arthritis', 'Asthma', 'Cancer', 'Diabetes',
#        'Chronic Obstructive Pulmonary Disease', 'Oral Health',
#        'Cardiovascular Disease', 'Immunization', 'Mental Health',
#        'Chronic Kidney Disease',
#        'Nutrition, Physical Activity, and Weight Status', 'Older Adults',
#        'Tobacco', 'Overarching Conditions', 'Reproductive Health',
#        'Disability'], dtype=object)

# %%
del csv_df["DataSource"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType DataValue  ...  LocationID TopicID QuestionID  \
# 0  Crude Prevalence      16.9  ...          59     ALC     ALC2_2
# ...

# %%
del csv_df["Response"]


csv_df.head
# Out:
# <bound method NDFrame.head of         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            2016     2016           US         United States
# 1            2016     2016           AL               Alabama
# 2            2016     2016           AK                Alaska
# 3            2016     2016           AZ               Arizona
# 4            2016     2016           AR              Arkansas
# 5            2016     2016           CA            California
# 6            2016     2016           CO              Colorado
# 7            2016     2016           CT           Connecticut
# 8            2016     2016           DE              Delaware
# 9            2016     2016           DC  District of Columbia
# 10           2016     2016           FL               Florida
# 11           2016     2016           GA               Georgia
# 12           2016     2016           HI                Hawaii
# 13           2016     2016           ID                 Idaho
# ...

# %%
del csv_df["DataValueType"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... LocationID  TopicID  QuestionID  \
# ...

# %%
del csv_df["TopicID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... ResponseID  LocationID  \
# 0          16.9                       *  ...        NaN          59
# ...

# %%
del csv_df["QuestionID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ...  \
# 0          16.9                       *  ...
# 1          13.0                     NaN  ...
# ...

# %%
del csv_df["DataValueTypeID"]

csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt DataValueFootnoteSymbol  ... Stratification3  \
# 0          16.9                       *  ...             NaN
# ...

# %%
del csv_df["StratificationCategoryID1"]

# %%
del csv_df["DataValueFootnoteSymbol"]

# %%
del csv_df["StratificationCategory3"]

# %%
del csv_df["Stratification3"]

# %%
del csv_df["DatavalueFootnote"]

# %%
del csv_df["LowConfidenceLimit"]

# %%
del csv_df["HighConfidenceLimit"]

# %%
del csv_df["StratificationCategory2"]

# %%
del csv_df["Stratification2"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt StratificationCategory1 Stratification1  \
# 0          16.9                 Overall         Overall
# ...

# %%
del csv_df["Stratification1"]

# %%
del csv_df["ResponseID"]

# %%
del csv_df["LocationID"]

# %%
del csv_df["StratificationID1"]

# %%
del csv_df["StratificationCategoryID2"]

# %%
del csv_df["StratificationID2"]

# %%
del csv_df["StratificationCategoryID3"]

# %%
del csv_df["StratificationID3"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc    Topic  \
# 0       2016     2016           US  United States  Alcohol
# 1       2016     2016           AL        Alabama  Alcohol
# 2       2016     2016           AK         Alaska  Alcohol
# 3       2016     2016           AZ        Arizona  Alcohol
# 4       2016     2016           AR       Arkansas  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 0  Binge drinking prevalence among adults aged >=...             %      16.9
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
#
#    DataValueAlt StratificationCategory1  \
# 0          16.9                 Overall
# 1          13.0                 Overall
# ...

# %%
csv_df = csv_df.dropna(how="any")

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#    DataValueAlt StratificationCategory1  \
# 1          13.0                 Overall
# 2          18.2                 Overall
# ...

# %%
del csv_df["DataValueAlt"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#   StratificationCategory1                                GeoLocation
# 1                 Overall    (32.84057112200048, -86.63186076199969)
# ...

# %%
csv_df_2 = csv_df["GeoLocation"].str.split(",", n = 1, expand = True) 

csv_df_2.head()
# Out:
#                      0                      1
# 1   (32.84057112200048    -86.63186076199969)
# 2   (64.84507995700051   -147.72205903599973)
# 3  (34.865970280000454   -111.76381127699972)
# 4   (34.74865012400045    -92.27449074299966)
# 5   (37.63864012300047   -120.99999953799971)

# %%
# csv_df['tmp'] = 9
# csv_df_2['tmp'] = 2

## csv_df_3 = pd.merge(csv_df, csv_df_2, on=['tmp'])
# csv_df_3.head()

# %%
csv_df["Latitude"] = csv_df_2[0]
csv_df.head()
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# ...

# %%
csv_df["Longitude"] = csv_df_2[1]
csv_df.head()
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# ...

# %%
del csv_df["GeoLocation"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GeoLocation'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-45f2b4d7d8b1> in <module>
# ...

# %%
# del csv_df["tmp"]

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#   StratificationCategory1             Latitude              Longitude
# 1                 Overall   (32.84057112200048    -86.63186076199969)
# ...

# %%
replace_lat = csv_df["Latitude"].str.replace("\(","")
csv_df_4 = pd.DataFrame(replace_lat)
csv_df_4.head()
# Out:
#              Latitude
# 1   32.84057112200048
# 2   64.84507995700051
# 3  34.865970280000454
# 4   34.74865012400045
# 5   37.63864012300047

# %%
csv_df["Latitude2"] = csv_df_4["Latitude"]
csv_df.head()
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# ...

# %%
replace_lng = csv_df["Longitude"].str.replace("\)","")
csv_df_5 = pd.DataFrame(replace_lng)
csv_df_5.head()
# Out:
#               Longitude
# 1    -86.63186076199969
# 2   -147.72205903599973
# 3   -111.76381127699972
# 4    -92.27449074299966
# 5   -120.99999953799971

# %%
csv_df["Longitude2"] = csv_df_5["Longitude"]
csv_df.head()
# Out:
# /Users/Pariah/anaconda3/envs/PythonData3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# ...

# %%
del csv_df["Latitude"]

# %%
del csv_df["Longitude"]

# %%
csv_df = csv_df.rename(columns={
    "Longitude2": "Longitude",
    "Latitude2": "Latitude"
})

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %        13
# 2  Binge drinking prevalence among adults aged >=...             %      18.2
# 3  Binge drinking prevalence among adults aged >=...             %      15.6
# 4  Binge drinking prevalence among adults aged >=...             %        15
# 5  Binge drinking prevalence among adults aged >=...             %      16.3
#
#   StratificationCategory1            Latitude             Longitude
# 1                 Overall   32.84057112200048    -86.63186076199969
# ...

# %%
csv_df.dtypes
# Out:
# YearStart                   int64
# YearEnd                     int64
# LocationAbbr               object
# LocationDesc               object
# Topic                      object
# Question                   object
# DataValueUnit              object
# DataValue                  object
# StratificationCategory1    object
# Latitude                   object
# Longitude                  object
# dtype: object

# %%
csv_df["DataValue"] = csv_df["DataValue"].astype(float)

# %%
csv_df.dtypes
# Out:
# YearStart                    int64
# YearEnd                      int64
# LocationAbbr                object
# LocationDesc                object
# Topic                       object
# Question                    object
# DataValueUnit               object
# DataValue                  float64
# StratificationCategory1     object
# Latitude                    object
# Longitude                   object
# dtype: object

# %%
csv_df["Longitude"] = csv_df["Longitude"].astype(float)
csv_df["Latitude"] = csv_df["Latitude"].astype(float)

# %%
csv_df.dtypes
# Out:
# YearStart                    int64
# YearEnd                      int64
# LocationAbbr                object
# LocationDesc                object
# Topic                       object
# Question                    object
# DataValueUnit               object
# DataValue                  float64
# StratificationCategory1     object
# Latitude                   float64
# Longitude                  float64
# dtype: object

# %%
csv_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc    Topic  \
# 1       2016     2016           AL      Alabama  Alcohol
# 2       2016     2016           AK       Alaska  Alcohol
# 3       2016     2016           AZ      Arizona  Alcohol
# 4       2016     2016           AR     Arkansas  Alcohol
# 5       2016     2016           CA   California  Alcohol
#
#                                             Question DataValueUnit  DataValue  \
# 1  Binge drinking prevalence among adults aged >=...             %       13.0
# 2  Binge drinking prevalence among adults aged >=...             %       18.2
# 3  Binge drinking prevalence among adults aged >=...             %       15.6
# 4  Binge drinking prevalence among adults aged >=...             %       15.0
# 5  Binge drinking prevalence among adults aged >=...             %       16.3
#
#   StratificationCategory1   Latitude   Longitude
# 1                 Overall  32.840571  -86.631861
# 2                 Overall  64.845080 -147.722059
# ...

# %%
output_csv = csv_df.to_csv("Cleaned_Chronic_Disease_Data_3.csv", index=False, header=True)
